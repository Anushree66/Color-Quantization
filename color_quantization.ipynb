# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_as_array = mpimg.imread("palm_tree.jpg")

# %%
image_as_array.shape
# Out:
# (1300, 1300, 3)

# %%
image_as_array
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.figure(dpi=200)
plt.imshow(image_as_array)

# %%
(h,w,c)=image_as_array.shape

# %%
image_as_array2d=image_as_array.reshape(h*w,c)

# %%
image_as_array2d
# Out:
# array([[255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        ...,
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255]], dtype=uint8)

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=3)

# %%
labels=model.fit_predict(image_as_array2d)

# %%
labels
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
model.cluster_centers_
# Out:
# array([[ 70.90690171, 199.80647801, 237.70785176],
#        [237.25035318, 245.65392132, 230.18483077],
#        [ 11.09769969,  13.9525665 ,  16.0398986 ]])

# %%
rgb_codes=model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[ 71, 200, 238],
#        [237, 246, 230],
#        [ 11,  14,  16]])

# %%
rgb_codes[labels]
# Out:
# array([[237, 246, 230],
#        [237, 246, 230],
#        [237, 246, 230],
#        ...,
#        [237, 246, 230],
#        [237, 246, 230],
#        [237, 246, 230]])

# %%
quantized_image=np.reshape(rgb_codes[labels],(h,w,c))

# %%
plt.imshow(quantized_image)

# %%
plt.imshow(image_as_array)
